# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import gcf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    roc_curve,
    roc_auc_score,
    confusion_matrix,
    balanced_accuracy_score,
    f1_score
)

# %% [markdown]
# Define directory path to save results

# %%
output_dir = '../results/updated_data/all_features/ovarianCancer/LPO_validation/feature_preselection/binary/random_oversampler_default/top25_proba/'

# %% [markdown]
# Load and prepare dataset

# %%
data_path = '../data/cleaned/updated/all_features/ovarianCancer/'
dataset = pd.read_csv(os.path.join(data_path, 'dataset.csv'), sep=';')

binary_mapping = {
    'I': 'I-III',
    'II': 'I-III',
    'III': 'I-III',
    'IV': 'IV'
}
dataset.loc[:, 'Stage'] = dataset['Stage'].map(binary_mapping)
dataset = dataset.loc[:, ~dataset.columns.isin(['Sex', 'Age', 'Group'])]

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Columns: 5328 entries, ID to CASC15
# dtypes: float64(5326), object(2)
# memory usage: 5.2+ MB

# %% [markdown]
# Load prediction results

# %%
initial_feature_importances_dir = '../results/updated_data/all_features/ovarianCancer/LPO_validation/backward_elimination/binary/random_oversampler_default/pred_proba/'

initial_feature_importances = pd.read_csv(os.path.join(initial_feature_importances_dir, 'feature_importances.csv'), sep=';')
initial_feature_importances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3290 entries, 0 to 3289
# Columns: 5326 entries, DPM1 to CASC15
# dtypes: float64(5326)
# memory usage: 133.7 MB

# %%
feature_importances = pd.read_csv(os.path.join(output_dir, 'feature_importances.csv'), sep=';')
predictions = pd.read_csv(os.path.join(output_dir, 'predictions.csv'), sep=';')

# %%
most_important_features_sorted = feature_importances.mean().sort_values(ascending=False)
# input_columns = most_important_features_sorted.index.tolist()
input_columns = most_important_features_sorted.index.tolist()[:50]
dataset = dataset.loc[:, input_columns + ['Stage', 'ID']]
dataset = dataset.sort_values(by='Stage')

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129 entries, 0 to 64
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KSR1      129 non-null    float64
#  1   HDAC8     129 non-null    float64
#  2   DDX11L10  129 non-null    float64
#  3   CLEC2L    129 non-null    float64
#  4   DDX11L5   129 non-null    float64
#  5   TAOK1     129 non-null    float64
#  6   CHD1      129 non-null    float64
#  7   NEMF      129 non-null    float64
#  8   PPP1R14A  129 non-null    float64
#  9   USP5      129 non-null    float64
#  10  CTNNBIP1  129 non-null    float64
#  11  CYC1      129 non-null    float64
#  12  MAP3K8    129 non-null    float64
#  13  HDAC1     129 non-null    float64
#  14  ITPR1     129 non-null    float64
#  15  TRAPPC12  129 non-null    float64
#  16  UQCRH     129 non-null    float64
#  17  TRNAU1AP  129 non-null    float64
#  18  CLTA      129 non-null    float64
#  19  DEK       129 non-null    float64
#  20  PNN       129 non-null    float64
#  21  BLNK      129 non-null    float64
#  22  ADAT1     129 non-null    float64
#  23  RAP1B     129 non-null    float64
#  24  CNOT6L    129 non-null    float64
#  25  Stage     129 non-null    object
#  26  ID        129 non-null    object
# dtypes: float64(25), object(2)
# memory usage: 28.2+ KB

# %% [markdown]
# ### Performance metrics

# %%
def calculate_metrics(predictions):
    balanced_accuracy = balanced_accuracy_score(predictions['y_true'], predictions['y_pred'])
    auc = roc_auc_score(predictions['y_true'], predictions['pred_proba'])
    f1 = f1_score(predictions['y_true'], predictions['y_pred'])
    
    tn, fp, fn, tp = confusion_matrix(predictions['y_true'], predictions['y_pred']).ravel()
    specificity = tn / (tn + fp)
    sensitivity = tp / (tp + fn)
    
    return pd.DataFrame({
        'Metric': ['Balanced Accuracy', 'AUC', 'F1', 'Specificity', 'Sensitivity'],
        'Score': [round(balanced_accuracy, 3), round(auc, 3), round(f1, 3), round(specificity, 3), round(sensitivity, 3)]
    })

# %%
metrics = calculate_metrics(predictions)
print(metrics)

metrics.to_csv(os.path.join(output_dir, 'performance_metrics.csv'), index=False, sep=';')
# Out:
#               Metric  Score
# 0  Balanced Accuracy  0.905
# 1                AUC  0.977
# 2                 F1  0.896
# 3        Specificity  0.989
# 4        Sensitivity  0.820

# %% [markdown]
# ### Figures

# %%
def plot_feature_importances(feature_importances_history, feature_names, top_n=25, filename=None):
    mean_importance_scores = np.mean(feature_importances_history, axis=0)
    top_feature_indices = np.argsort(mean_importance_scores)[-1:-top_n-1:-1]
    
    top_feature_importances = feature_importances_history[:, top_feature_indices]
    top_feature_names = feature_names[top_feature_indices]
    
    sns.set_style('whitegrid')
    fig, ax = plt.subplots(figsize=(11.7, 8.27))
    bar = sns.barplot(x=mean_importance_scores[top_feature_indices], y=top_feature_names, color='#0077b6')
    for b in ax.containers[0]:
        b.set_alpha(0.7)
    
    ax_box = bar.twinx()
    box = sns.boxplot(data=top_feature_importances, orient='h', color='#051923', fill=False, linewidth=1., fliersize=1.8, ax=ax_box)
    ax.set_xlim(left=-0.0001)
    ax_box.set_yticks([])
    
    x_axis_label = 'Importance Score'
    y_axis_label = f'Feature Name'
    
    ax.set_xlabel(x_axis_label, fontsize=14)
    ax.set_ylabel(y_axis_label, fontsize=14)
    
    xlabels = [xtick.get_text() for xtick in bar.get_xticklabels()]
    ax.set_xticklabels(xlabels, size=12)

    ylabels = [ytick.get_text() for ytick in bar.get_yticklabels()]
    ax.set_yticklabels(ylabels, size=10)
    
    if filename is not None:
        fig.savefig(filename, bbox_inches='tight')
    
    fig.show()

# %%
top_n = 25
filename = f'feature_importances_top_{top_n}.png'
output_path = os.path.join(output_dir, filename)

plot_feature_importances(initial_feature_importances.values, initial_feature_importances.columns, top_n, output_path)
# Out:
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\3086039125.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xlabels, size=12)
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\3086039125.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylabels, size=10)
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\3086039125.py:34: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def plot_heatmap(dataset, input_features, filename=None):
    input_features = dataset.loc[:, input_columns]

    scaler = MinMaxScaler()
    input_features = scaler.fit_transform(input_features)
    df_vis = pd.DataFrame(data=input_features, columns=input_columns, index=dataset.loc[:, 'Stage'].values).T

    stages = df_vis.columns
    stages_color_pallete = ['#0077b6', '#023e8a']
    stages_color_mapping = dict(zip(stages.unique(), stages_color_pallete))
    stages_colors = pd.Series(stages, index=stages, name='Stage').map(stages_color_mapping)

    fig = sns.clustermap(
        df_vis,
        row_cluster=False,
        col_cluster=False,
        col_colors=stages_colors,
        linewidths=0,
        xticklabels=False,
        yticklabels=input_columns,
        center=0.5,
        cmap='Blues',
        cbar_pos=(0.4, 0.825, 0.5, 0.013),
        cbar_kws={
            'orientation': 'horizontal'
        },
        figsize=(11.7, 13),
        colors_ratio=0.017
    )

    fig.cax.set_title(label='Min-max scaled feature values', fontdict={'fontsize': 14})

    stage_tick_label = fig.ax_col_colors.axes.get_yticklabels()[0]
    stage_tick_label.set_fontsize(12)
    stage_tick_label.set_fontweight('bold')

    for tick_label in fig.ax_heatmap.axes.get_yticklabels():
        tick_label.set_fontsize(10)

    for spine in fig.ax_cbar.spines:
        fig.ax_cbar.spines[spine].set_color('black')
        fig.ax_cbar.spines[spine].set_linewidth(0.8)

    for stage in stages.unique():
        fig.ax_col_dendrogram.bar(0, 0, color=stages_colors[stage], label=stage, linewidth=0, )

    legend = fig.ax_col_dendrogram.legend(title='Stage', title_fontsize=14, loc='lower left', ncol=2, bbox_to_anchor=(0.19, 0.805), prop={'size': 12},
                                          bbox_transform=gcf().transFigure, edgecolor='#000000')
    
    if output_path is not None:
        plt.savefig(filename, bbox_inches='tight')
    
    plt.show()

# %%
output_path = os.path.join(output_dir, 'heatmap.png')
plot_heatmap(dataset, input_columns, output_path)

# %%
def plot_boxplots(predictions, mapping, filename=None):
    preds_vis = predictions.copy(deep=True)

    preds_vis_grouped = preds_vis.groupby(by=['id', 'y_true'], as_index=False)['pred_proba'].mean()
    preds_vis_grouped.loc[:, 'y_true'] = preds_vis_grouped['y_true'].map(mapping)
    
    x_axis_label = 'Stage'
    y_axis_label = f'Predicted probability of stage {mapping[1]}'
    preds_vis_grouped = preds_vis_grouped.rename(columns={'y_true': x_axis_label, 'pred_proba': y_axis_label})
    
    sns.set_style('whitegrid')
    plt.figure(figsize=(11.7, 8.27))
    plt.ylim(0, 1.05)
    
    fig = sns.boxplot(
        data=preds_vis_grouped,
        x=x_axis_label,
        y=y_axis_label,
        orient='v',
        showfliers=False,
        color='#0077b6',
        linewidth=1.5
    )
    for patch in fig.patches:
        r, g, b, a = patch.get_facecolor()
        patch.set_facecolor((r, g, b, .3))
        
    fig2 = sns.swarmplot(
        data=preds_vis_grouped,
        x=x_axis_label,
        y=y_axis_label,
        orient='v',
        alpha=1.,
        color='#023e8a'
    )
    fig.set_xlabel(x_axis_label, fontsize=14)
    fig.set_ylabel(y_axis_label, fontsize=14)

    _, xlabels = plt.xticks()
    fig.set_xticklabels(xlabels, size=12)

    _, ylabels = plt.yticks()
    fig.set_yticklabels(ylabels, size=12)
    
    if filename is not None:
        plt.savefig(filename, bbox_inches='tight')
        
    plt.show()

# %%
mapping = {0: 'I-III', 1: 'IV'}
output_path = os.path.join(output_dir, 'boxplots.png')
plot_boxplots(predictions, mapping, output_path)
# Out:
# C:\Users\szyko\anaconda3\envs\cancer_stage_prediction\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 13.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\1807258724.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.set_xticklabels(xlabels, size=12)
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\1807258724.py:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.set_yticklabels(ylabels, size=12)
# C:\Users\szyko\anaconda3\envs\cancer_stage_prediction\lib\site-packages\seaborn\categorical.py:3370: UserWarning: 16.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
def find_nearest(array: np.array, value: float):
    idx = (np.abs(array - value)).argmin()
    return idx


def plot_roc_auc_curve(predictions, selected_thresholds, filename=None):
    fpr, tpr, thresholds = roc_curve(predictions['y_true'], predictions['pred_proba'])
    auc = roc_auc_score(predictions['y_true'], predictions['pred_proba'])

    sns.set_style('whitegrid')
    plt.figure(figsize=(11.7, 8.27))
    
    plt.plot([0, 0, 1], [0, 1, 1], color='#3cb043', linewidth=2, linestyle='dashed', label=f'Perfect classifier (AUC = 1.0)')
    plt.plot([0, 1], [0, 1], color='#ff0000', linewidth=2, linestyle='dashed', label=f'Random classifier (AUC = 0.5)')
    
    plt.plot(fpr, tpr, color='#023e8a', linewidth=2, label=f'XGBClassifier (AUC = {auc:.3f})')
    plt.fill_between(fpr, tpr, color='#0077b6', alpha=0.2)
    
    selected_indices = np.zeros_like(selected_thresholds, dtype=int)
    for i, thresh in enumerate(selected_thresholds):
        closest_idx = find_nearest(thresholds, thresh)
        selected_indices[i] = closest_idx
        plt.annotate(np.round(thresh, 2), (fpr[closest_idx] + 0.005, tpr[closest_idx] - 0.03), size=12)

    plt.scatter(fpr[selected_indices], tpr[selected_indices], color='#023e8a', linewidth=2, marker='.', s=100, label='Probability thresholds')

    plt.xlabel('False positive rate', fontsize=14)
    plt.ylabel('True positive rate', fontsize=14)
    plt.ylim(0, 1.05)
    plt.xlim(-0.05, 1.)
    plt.legend(loc='lower right', prop={'size': 12})
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    if filename is not None:
        plt.savefig(filename, bbox_inches='tight')

    plt.show()

# %%
selected_thresholds = [0.01, 0.1, 0.2, 0.5, 0.95]

output_path = os.path.join(output_dir, 'roc_auc_curve2.png')
plot_roc_auc_curve(predictions, selected_thresholds, output_path)

# %%
def plot_confusion_matrix(predictions, labels, filename=None):
    cm = confusion_matrix(predictions['y_true'], predictions['y_pred'], normalize='all')
    cm *= 100

    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    df_annots = df_cm.applymap(lambda x: f'{x:.2f}%')
    fig, ax = plt.subplots(figsize=(11.7, 8.27))
    sns.heatmap(df_cm, annot=df_annots, cmap='Blues', fmt='', linewidths=1, annot_kws={'fontsize': 12},
                cbar_kws={'label': 'Percentage of all tested samples'})
    ax.figure.axes[-1].yaxis.label.set_size(14)
    ax.set_ylabel('True Stage', fontdict={'size': 14})
    ax.set_xlabel('Predicted Stage', fontdict={'size': 14})
    ax.xaxis.set_ticks_position('top')
    ax.xaxis.set_label_position('top')
    ax.xaxis.set_ticks_position('none')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    if filename is not None:
        plt.savefig(filename, bbox_inches='tight')

    fig.show()

# %%
labels = list(mapping.values())

output_path = os.path.join(output_dir, 'confusion_matrix.png')
plot_confusion_matrix(predictions, labels, output_path)
# Out:
# C:\Users\szyko\AppData\Local\Temp\ipykernel_42488\3923249889.py:22: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
